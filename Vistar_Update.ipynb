# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkS0001/IIT-Bombay-Whisper-Hindi-ASR-Model-Machine-Learning-Intern/blob/main/Vistar_Update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Apr 28 05:46:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.4 MB/s eta 0:00:00
# ...

# %%
import whisper

model = whisper.load_model("large")
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:27<00:00, 35.4MiB/s]

# %%
# !git clone https://github.com/AI4Bharat/vistaar
# Out:
# Cloning into 'vistaar'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 157 (delta 4), reused 0 (delta 0), pack-reused 145
# Receiving objects: 100% (157/157), 58.71 KiB | 7.34 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar/kathbath.zip
# Out:
# --2024-04-28 05:51:34--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar/kathbath.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 101.53.136.19, 164.52.210.97, 164.52.210.58, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|101.53.136.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9187772731 (8.6G) [application/zip]
# Saving to: ‘kathbath.zip’
#
# kathbath.zip         14%[=>                  ]   1.26G  --.-KB/s    eta 37m 56s^C

# %%
pip install -r /content/vistaar/requirements.txt
# Out:
# ...
#   Cloning https://github.com/yt-dlp/yt-dlp.git to /tmp/pip-req-build-nh1tr9mz
#   Running command git clone --filter=blob:none --quiet https://github.com/yt-dlp/yt-dlp.git /tmp/pip-req-build-nh1tr9mz
#   Resolved https://github.com/yt-dlp/yt-dlp.git to commit 64766459e37451b665c1464073c28361fbcf1c25
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-zis_rojn
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-zis_rojn
#   Resolved https://github.com/huggingface/transformers to commit 73014b561d5f88d728e46a57d346f516fefe3f2d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/datasets to /tmp/pip-req-build-riijc8j1
# ...

# %%
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar/kathbath.zip
# Out:
# --2024-04-28 05:58:31--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar/kathbath.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.210.58, 164.52.206.155, 164.52.210.97, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.210.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9187772731 (8.6G) [application/zip]
# Saving to: ‘kathbath.zip.1’
#
# kathbath.zip.1      100%[===================>]   8.56G  13.1MB/s    in 11m 29s
#
# 2024-04-28 06:10:03 (12.7 MB/s) - ‘kathbath.zip.1’ saved [9187772731/9187772731]

# %%
# !unzip kathbath.zip.1
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: kathbath/kannada/test_known/audio/324/844424930763908-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930724288-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930645739-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930978495-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930900106-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930581430-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930526312-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930663936-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930958297-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930987547-324-f.wav
#   inflating: kathbath/kannada/test_known/audio/324/844424930547788-324-f.wav
# ...

# %%
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar_benchmarks/kathbath.zip
# Out:
# --2024-04-28 06:14:22--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/vistaar_benchmarks/kathbath.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 101.53.152.30, 164.52.206.154, 164.52.210.97, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|101.53.152.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3457654951 (3.2G) [application/zip]
# Saving to: ‘kathbath.zip.2’
#
# kathbath.zip.2      100%[===================>]   3.22G  13.2MB/s    in 4m 27s
#
# 2024-04-28 06:18:51 (12.4 MB/s) - ‘kathbath.zip.2’ saved [3457654951/3457654951]

# %%
# !unzip kathbath.zip.2
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: kathbath/tamil/wavs/844424933226093-131-m.wav
#   inflating: kathbath/tamil/wavs/844424930425733-685-f.wav
#   inflating: kathbath/tamil/wavs/844424930592589-47-f.wav
#   inflating: kathbath/tamil/wavs/844424930452982-1009-f.wav
#   inflating: kathbath/tamil/wavs/844424930705398-709-f.wav
#   inflating: kathbath/tamil/wavs/844424930743365-877-f.wav
#   inflating: kathbath/tamil/wavs/844424933409713-128-m.wav
#   inflating: kathbath/tamil/wavs/844424933243254-109-m.wav
#   inflating: kathbath/tamil/wavs/844424933226027-311-m.wav
#   inflating: kathbath/tamil/wavs/844424930743306-877-f.wav
#   inflating: kathbath/tamil/wavs/844424933409678-128-m.wav
#   inflating: kathbath/tamil/wavs/844424930453006-1009-f.wav
#   inflating: kathbath/tamil/wavs/844424930669837-685-f.wav
#   inflating: kathbath/tamil/wavs/844424933236932-311-m.wav
#   inflating: kathbath/tamil/wavs/844424930743301-877-f.wav
# ...

# %%
# !wget https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/all_lang_models/hindi_models.zip
# Out:
# --2024-04-28 06:21:50--  https://objectstore.e2enetworks.net/indic-asr-public/indicwhisper/all_lang_models/hindi_models.zip
# Resolving objectstore.e2enetworks.net (objectstore.e2enetworks.net)... 164.52.206.154, 101.53.152.30, 164.52.210.57, ...
# Connecting to objectstore.e2enetworks.net (objectstore.e2enetworks.net)|164.52.206.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4262614425 (4.0G) [application/zip]
# Saving to: ‘hindi_models.zip’
#
# hindi_models.zip    100%[===================>]   3.97G  11.5MB/s    in 5m 13s
#
# 2024-04-28 06:27:06 (13.0 MB/s) - ‘hindi_models.zip’ saved [4262614425/4262614425]

# %%
# !unzip hindi_models.zip
# Out:
# Archive:  hindi_models.zip
#    creating: hindi_models/
#    creating: hindi_models/whisper-large-hi-noldcil/
#   inflating: hindi_models/whisper-large-hi-noldcil/tokenizer_config.json
#   inflating: hindi_models/whisper-large-hi-noldcil/merges.txt
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_1.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_0.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/vocab.json
#   inflating: hindi_models/whisper-large-hi-noldcil/added_tokens.json
#   inflating: hindi_models/whisper-large-hi-noldcil/training_args.bin
#  extracting: hindi_models/whisper-large-hi-noldcil/latest
#   inflating: hindi_models/whisper-large-hi-noldcil/zero_to_fp32.py
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_2.pth
#   inflating: hindi_models/whisper-large-hi-noldcil/trainer_state.json
#   inflating: hindi_models/whisper-large-hi-noldcil/rng_state_3.pth
# ...

# %%
# %cd /content/vistaar
# Out:
# /content/vistaar

# %%
# !python evaluation.py --model_path=/content/hindi_models/whisper-large-hi-noldcil \
--manifest_path=/content/kathbath/hindi/manifest.json \
--manifest_name=hindi \
--device=0 \
--batch_size=100 \
--language=hi
# Out:
# 2024-04-28 06:57:57.934734: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 06:57:57.934787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 06:57:57.936333: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 06:57:57.944041: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python evaluation.py --model_path /content/hindi_models/whisper-large-hi-noldcil --manifest_path /content/kathbath/hindi/manifest.json --manifest_name kathbath --device 0 --batch_size 32 --language hi
# Out:
# 2024-04-28 06:44:26.839383: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 06:44:26.839432: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 06:44:26.841026: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 06:44:26.848645: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
